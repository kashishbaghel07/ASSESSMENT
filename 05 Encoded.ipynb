# %% [markdown]
# # Encoding

# %% [raw]
# 1) What is Encoding?
#
# Encoding means converting text (categorical data) into numbers.
#
# Machine learning models understand numbers only, not text.
#
# So we must convert categories like "Male", "Delhi", "Electronics" into numeric form.
#
# 2) Why Encoding is Needed?
#
# ML algorithms cannot read strings.
#
# Encoding helps convert categories to numeric values.
#
# Different encoding methods keep or remove category relationships depending on the method.
#
# Good encoding improves model performance.

# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("C:\\Users\\Kashish\\Downloads\\encoding_practice.csv")

# %%
# Add a simple numeric target column
# (Target Encoding needs a number column)
# ------------------------------------------------------------

# Base spend value for each category
base_spend = {
    "Grocery": 1200,
    "Clothing": 2500,
    "Electronics": 6000,
    "Furniture": 8000
}

# %%
# Create a simple target value (Monthly_Spend)
# We add a small extra amount using ID so values are not same
df["Monthly_Spend"] = df.apply(
    lambda row: base_spend[row["Purchase_Category"]] + (row["ID"] % 7) * 50,
    axis=1
)

# %%
# List of all categorical columns
cat_cols = ["Gender", "City", "Education", "Marital_Status", "Purchase_Category"]

df.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend
# 0           6050
# 1           2600
# 2           1350
# 3           6200
# 4           2750

# %% [raw]
# 1. Label Encoding
#
# Definition:
#
# Converts each category into a unique integer 0, 1, 2, 3...
#
# Example: Gender → Male=0, Female=1, Other=2
#
# Fast and simple, but creates fake ordering between categories.
#
# Use When:
#
# Categories are not related to each other and models like trees are used.
#
# Not Good For:
#
# Linear models, because numbers create false ranking.

# %%
# LABEL ENCODING
# Definition:
# Converts each category into an integer like 0,1,2...
# Good for simple models, but numbers imply order (problem).
# ------------------------------------------------------------

df_le = df.copy()

for col in cat_cols:
    codes, uniques = pd.factorize(df_le[col])     # convert text → number
    df_le[col + "_LE"] = codes

df_le.to_csv("label_encoded.csv", index=False)
df_le.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend  Gender_LE  City_LE  Education_LE  Marital_Status_LE  \
# 0           6050          0        0             0                  0
# 1           2600          1        1             1                  1
# 2           1350          0        2             2                  0
# 3           6200          2        3             0                  0
# 4           2750          1        4             2                  1
#
#    Purchase_Category_LE
# 0                     0
# 1                     1
# 2                     2
# ...

# %% [raw]
# 2. One-Hot Encoding
#
# Definition:
#
# Creates new columns for each category with 0 or 1.
#
# Example: Gender → Gender_Male, Gender_Female, Gender_Other
#
# Removes false ordering.
#
# Use When:
#
# Categories are small in count (3–10 labels).
#
# Disadvantage:
#
# Increases number of columns a lot (high dimensionality).

# %%
# ONE-HOT ENCODING
# Definition:
# Creates new columns like Gender_Male, Gender_Female with 0/1.
# No fake ordering but increases number of columns.
# ------------------------------------------------------------

df_ohe = pd.get_dummies(df, columns=cat_cols, prefix=cat_cols, drop_first=False)

df_ohe.to_csv("one_hot_encoded.csv", index=False)
df_ohe.head()
# Out:
#    ID  Monthly_Spend  Gender_Female  Gender_Male  Gender_Other  \
# 0   1           6050          False         True         False
# 1   2           2600           True        False         False
# 2   3           1350          False         True         False
# 3   4           6200          False        False          True
# 4   5           2750           True        False         False
#
#    City_Bangalore  City_Chennai  City_Delhi  City_Mumbai  City_Pune  \
# 0           False         False        True        False      False
# 1           False         False       False         True      False
# 2           False          True       False        False      False
# 3           False         False       False        False       True
# 4            True         False       False        False      False
#
#    Education_Graduate  Education_HighSchool  Education_Postgraduate  \
# 0                True                 False                   False
# ...

# %% [raw]
# 3. Ordinal Encoding
#
# Definition:
#
# Converts categories into numbers with meaningful order.
#
# Example:
#
# Education: HighSchool=0 < Graduate=1 < Postgraduate=2
#
# Sunday < Monday < Tuesday
#
# Use When:
#
# Categories have natural ranking.
#
# Do NOT Use When:
#
# Categories do not have real order (e.g., City names).

# %%
# ORDINAL ENCODING
# Definition:
# Converts categories into integers but WITH A MEANINGFUL ORDER.
# Example: HighSchool < Graduate < Postgraduate
# ------------------------------------------------------------

ordinal_maps = {
    "Education": {"HighSchool": 0, "Graduate": 1, "Postgraduate": 2},
    "Marital_Status": {"Single": 0, "Married": 1},
    "Gender": {"Other": 0, "Female": 1, "Male": 2},
    "City": {"Delhi": 0, "Mumbai": 1, "Chennai": 2, "Pune": 3, "Bangalore": 4},
    "Purchase_Category": {"Grocery": 0, "Clothing": 1, "Electronics": 2, "Furniture": 3}
}

df_ord = df.copy()

for col, mapping in ordinal_maps.items():
    df_ord[col + "_ORD"] = df_ord[col].map(mapping)

df_ord.to_csv("ordinal_encoded.csv", index=False)
df_ord.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend  Education_ORD  Marital_Status_ORD  Gender_ORD  City_ORD  \
# 0           6050              1                   0           2         0
# 1           2600              2                   1           1         1
# 2           1350              0                   0           2         2
# 3           6200              1                   0           0         3
# 4           2750              0                   1           1         4
#
#    Purchase_Category_ORD
# 0                      2
# 1                      1
# ...

# %% [raw]
# 4. Binary Encoding
#
# Definition:
#
# Two-step process:
#
# Convert category → integer
#
# Convert integer → binary digits (0/1)
#
# Example:
#
# If “Mumbai” → 3 → binary "11" → [1,1]
#
# Use When:
#
# Categories are many (20–100+).
#
# Reduces column explosion compared to One-Hot.
#
# Benefit:
#
# More compact, less memory used.

# %%
# BINARY ENCODING (manual beginner-friendly method)
# Definition:
# Step 1: Convert category → integer
# Step 2: Convert integer → binary digits (0/1)
# Useful when many categories exist.
# ------------------------------------------------------------

df_bin = df.copy()

# Factorize: convert categories to integers
codes, unique_vals = pd.factorize(df_bin["City"])
codes = codes.astype(int)

# How many bits needed?
n_unique = len(unique_vals)
n_bits = int(math.ceil(math.log2(n_unique))) if n_unique > 1 else 1

df_bin["City_CODE"] = codes

# Create binary columns
for bit in range(n_bits):
    df_bin[f"City_BIN_{bit}"] = (codes >> bit) & 1   # shift and take bit

df_bin.to_csv("binary_encoded_city.csv", index=False)
df_bin.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend  City_CODE  City_BIN_0  City_BIN_1  City_BIN_2
# 0           6050          0           0           0           0
# 1           2600          1           1           0           0
# 2           1350          2           0           1           0
# 3           6200          3           1           1           0
# 4           2750          4           0           0           1

# %% [raw]
# 5. Target Encoding
#
# Definition:
#
# Replace each category with the mean value of the target for that category.
#
# Example:
#
# If “Electronics” customers spend Avg ₹6000 → Electronics = 6000
#
# Helps models learn category impact on target.
#
# Use When:
#
# Working with high-cardinality columns (many categories).
#
# Predictive problems (Regression or Classification).
#
# Warning:
#
# Can cause overfitting
#
# Should use smoothing or cross-validation in real projects.

# %%
# TARGET ENCODING
# Definition:
# Replace category with MEAN of target value for that category.
# Example: Clothing → average Monthly_Spend for Clothing customers.
# ------------------------------------------------------------

df_te = df.copy()

means = df.groupby("Purchase_Category")["Monthly_Spend"].mean()
df_te["Purchase_Category_TE"] = df_te["Purchase_Category"].map(means)

df_te.to_csv("target_encoded.csv", index=False)
df_te.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend  Purchase_Category_TE
# 0           6050           6139.285714
# 1           2600           2627.272727
# 2           1350           1353.846154
# 3           6200           6139.285714
# 4           2750           2627.272727

# %% [raw]
# 6. Frequency Encoding
#
# Definition:
#
# Replace each category with how often it appears.
#
# Example:
#
# If “Delhi” appears 12 times → Delhi = 12
#
# Can also normalize: “Delhi” = 12/50 = 0.24
#
# Use When:
#
# Category frequency matters
#
# Good for tree-based models.
#
# Benefit:
#
# Very compact
#
# No column explosion.

# %%
# FREQUENCY ENCODING
# Definition:
# Replace category with how many times it appears in the column.
# Example: City with 10 rows → value becomes 10.
# ------------------------------------------------------------

df_fe = df.copy()

freq = df["City"].value_counts()
freq_norm = df["City"].value_counts(normalize=True)  # percentage

df_fe["City_FREQ"] = df_fe["City"].map(freq)
df_fe["City_FREQ_NORM"] = df_fe["City"].map(freq_norm)

df_fe.to_csv("frequency_encoded.csv", index=False)
df_fe.head()
# Out:
#    ID  Gender       City     Education Marital_Status Purchase_Category  \
# 0   1    Male      Delhi      Graduate         Single       Electronics
# 1   2  Female     Mumbai  Postgraduate        Married          Clothing
# 2   3    Male    Chennai    HighSchool         Single           Grocery
# 3   4   Other       Pune      Graduate         Single       Electronics
# 4   5  Female  Bangalore    HighSchool        Married          Clothing
#
#    Monthly_Spend  City_FREQ  City_FREQ_NORM
# 0           6050         10             0.2
# 1           2600         10             0.2
# 2           1350         10             0.2
# 3           6200         10             0.2
# 4           2750         10             0.2

# %%
#Label Encoding
df_le.to_csv("label_encoded.csv", index=False)
#One-Hot Encoding
df_ohe.to_csv("one_hot_encoded.csv", index=False)
#Ordinal Encoding
df_ord.to_csv("ordinal_encoded.csv", index=False)
#Binary Encoding
df_bin.to_csv("binary_encoded_city.csv", index=False)
#Target Encoding
df_te.to_csv("target_encoded.csv", index=False)
#Frequency Encoding
df_fe.to_csv("frequency_encoded.csv", index=False)
print("saved")
# Out:
# saved

# %% [raw]
# When to Use Which Encoding
#
# | Encoding Type          | When to Use                                                      | When NOT to Use                                            | Best Models                                                       | Example Use Case                                          |
# | ---------------------- | ---------------------------------------------------------------- | ---------------------------------------------------------- | ----------------------------------------------------------------- | --------------------------------------------------------- |
# | **Label Encoding**     | When categories are small and order does not matter              | When using linear/logistic regression (creates fake order) | Decision Tree, Random Forest, XGBoost, LightGBM                   | Gender, City, Product Type                                |
# | **One-Hot Encoding**   | When categories are small (2–10 values) and no order exists      | When categories are large (20+), causes too many columns   | Linear Regression, Logistic Regression, SVM, KNN, Neural Networks | Gender, Marital Status, Education Level                   |
# | **Ordinal Encoding**   | When categories have natural order                               | When categories have no real ranking (City, Gender)        | Any model (trees or linear)                                       | Low < Medium < High, HighSchool < Graduate < Postgraduate |
# | **Binary Encoding**    | When categories are many (20–200+) and one-hot becomes too large | When categories are very few (not needed)                  | Linear models, Trees, KNN                                         | City names with 100 values, Product IDs                   |
# | **Target Encoding**    | When categories influence target and are high-cardinality        | Small datasets (risk of overfitting)                       | Tree models, Gradient Boosting, ML competitions                   | Predicting spending based on Product Category             |
# | **Frequency Encoding** | When want simple numeric value without many columns              | When frequency does not represent real meaning             | Tree models (RF, XGBoost, LightGBM)                               | City count, Product type frequency                        |
